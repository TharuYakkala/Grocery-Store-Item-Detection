# %% [markdown]
# # Results Analysis

# %%
from src.analysis import generate_model_plots, variance_analyzer, best_params_per_model
history_path = "./dataset/model_results/all_history.csv"

# %%
generate_model_plots(history_path=history_path)
# Out:
# c:\Users\silva\OneDrive - Toronto Metropolitan University (TMU)\MSc - Data Sci\Sem 2\4. DS8013 - Deep Learning\Assignments\Final Group\src\analysis\plotter.py:59: UserWarning: Plot visuals exists, skipping save.
#   warnings.warn("Plot visuals exists, skipping save.")
# c:\Users\silva\OneDrive - Toronto Metropolitan University (TMU)\MSc - Data Sci\Sem 2\4. DS8013 - Deep Learning\Assignments\Final Group\src\analysis\plotter.py:59: UserWarning: Plot visuals exists, skipping save.
#   warnings.warn("Plot visuals exists, skipping save.")
# c:\Users\silva\OneDrive - Toronto Metropolitan University (TMU)\MSc - Data Sci\Sem 2\4. DS8013 - Deep Learning\Assignments\Final Group\src\analysis\plotter.py:59: UserWarning: Plot visuals exists, skipping save.
#   warnings.warn("Plot visuals exists, skipping save.")
# ...

# %%
variance_analyzer(history_path=history_path)

# %%
best_params_per_model(history_path=history_path, metric='test_loss')
# Out:
#            model_name  dropout      wd  test_loss
# 0     efficientnet_b0     0.75  0.0010     1.4829
# 1  mobilenet_v3_small     0.75  0.0001     1.4054
# 2            resnet18     0.20  0.0001     1.4552
# 3               vgg16     0.75  0.0010     3.3841

# %%
best_params_per_model(history_path=history_path, metric='test_acc')
# Out:
#            model_name  dropout      wd  test_acc
# 0     efficientnet_b0     0.75  0.0005    0.3788
# 1  mobilenet_v3_small     0.75  0.0010    0.4211
# 2            resnet18     0.50  0.0001    0.3922
# 3               vgg16     0.50  0.0005    0.4065
